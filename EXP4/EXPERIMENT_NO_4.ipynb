# %%
#4 Getting the dataset continuation

import pandas as pd

# %%
#a Removing null values
ds = pd.read_csv("WDI_Country.csv")

# %%
# verifying for null values
ds.isnull()
# Out:
#      Country Code  Short Name  Table Name  Long Name  2-alpha code  \
# 0           False       False       False      False         False
# 1           False       False       False      False         False
# 2           False       False       False      False         False
# 3           False       False       False      False         False
# 4           False       False       False      False         False
# ..            ...         ...         ...        ...           ...
# 258         False       False       False      False         False
# 259         False       False       False      False         False
# 260         False       False       False      False         False
# 261         False       False       False      False         False
# 262         False       False       False      False         False
#
#      Currency Unit  Special Notes  Region  Income Group  WB-2 code  ...  \
# 0            False          False   False         False      False  ...
# ...

# %%
# removing nulls
ds.shape
# Out:
# (263, 31)

# %%
# remoing of all values in column are null
ds.dropna(how='all',axis=1).shape
# Out:
# (263, 31)

# %%
# remoing of all values in row are null
ds.dropna(how='all',axis=0).shape
# Out:
# (263, 31)

# %%
# remoing of any values in row are null
ds.dropna(axis=0).shape
# Out:
# (0, 31)

# %%
#viewing
ds.dropna(axis=0)
# Out:
# Empty DataFrame
# Columns: [Country Code, Short Name, Table Name, Long Name, 2-alpha code, Currency Unit, Special Notes, Region, Income Group, WB-2 code, National accounts base year, National accounts reference year, SNA price valuation, Lending category, Other groups, System of National Accounts, Alternative conversion factor, PPP survey year, Balance of Payments Manual in use, External debt Reporting status, System of trade, Government Accounting concept, IMF data dissemination standard, Latest population census, Latest household survey, Source of most recent Income and expenditure data, Vital registration complete, Latest agricultural census, Latest industrial data, Latest trade data, Latest water withdrawal data]
# Index: []
#
# [0 rows x 31 columns]

# %%
# remoing of any values in column are null
ds.dropna(axis=1).shape
# Out:
# (263, 4)

# %%
#viewing
ds.dropna(axis=1).head(10)
# Out:
#   Country Code            Short Name            Table Name  \
# 0          ABW                 Aruba                 Aruba
# 1          ADO               Andorra               Andorra
# 2          AFG           Afghanistan           Afghanistan
# 3          AGO                Angola                Angola
# 4          ALB               Albania               Albania
# 5          ARB            Arab World            Arab World
# 6          ARE  United Arab Emirates  United Arab Emirates
# 7          ARG             Argentina             Argentina
# 8          ARM               Armenia               Armenia
# 9          ASM        American Samoa        American Samoa
#
#                       Long Name
# 0                         Aruba
# 1       Principality of Andorra
# 2  Islamic State of Afghanistan
# 3   People's Republic of Angola
# 4           Republic of Albania
# 5                    Arab World
# 6          United Arab Emirates
# 7            Argentine Republic
# ...

# %%
#b understamding your variables
ds.dtypes
# Out:
# Country Code                                          object
# Short Name                                            object
# Table Name                                            object
# Long Name                                             object
# 2-alpha code                                          object
# Currency Unit                                         object
# Special Notes                                         object
# Region                                                object
# Income Group                                          object
# WB-2 code                                             object
# National accounts base year                           object
# National accounts reference year                      object
# SNA price valuation                                   object
# Lending category                                      object
# Other groups                                          object
# ...

# %%
ds.describe()
# Out:
#        Latest industrial data  Latest trade data  Latest water withdrawal data
# count              116.000000         190.000000                    181.000000
# mean              2009.810345        2013.000000                   2005.861878
# std                  3.270192           2.804003                      4.757186
# min               2000.000000        1995.000000                   1975.000000
# 25%               2010.000000        2014.000000                   2003.000000
# 50%               2011.000000        2014.000000                   2006.000000
# 75%               2012.000000        2014.000000                   2010.000000
# max               2012.000000        2014.000000                   2014.000000

# %%
#c relationship between continuous variables
ds
# Out:
#     Country Code       Short Name        Table Name  \
# 0            ABW            Aruba             Aruba
# 1            ADO          Andorra           Andorra
# 2            AFG      Afghanistan       Afghanistan
# 3            AGO           Angola            Angola
# 4            ALB          Albania           Albania
# ..           ...              ...               ...
# 258          YEM            Yemen       Yemen, Rep.
# 259          ZAF     South Africa      South Africa
# 260          ZAR  Dem. Rep. Congo  Congo, Dem. Rep.
# 261          ZMB           Zambia            Zambia
# 262          ZWE         Zimbabwe          Zimbabwe
#
#                             Long Name 2-alpha code       Currency Unit  \
# 0                               Aruba           AW       Aruban florin
# 1             Principality of Andorra           AD                Euro
# 2        Islamic State of Afghanistan           AF      Afghan afghani
# ...

# %%
ds.iloc[:,-1]
# Out:
# 0         NaN
# 1         NaN
# 2      2000.0
# 3      2005.0
# 4      2006.0
#         ...
# 258    2005.0
# 259    2000.0
# 260    2005.0
# 261    2002.0
# 262    2002.0
# Name: Latest water withdrawal data, Length: 263, dtype: float64

# %%
x = ds.iloc[:,-1]

# %%
type(x)
# Out:
# pandas.core.series.Series

# %%
#converting series to a list
X = x.tolist()

# %%
#similarly for another variable y
Y = ds.iloc[:,-2].tolist()

# %%
#importing pyplot for showing the relationship
import matplotlib.pyplot as plt

# %%
plt.scatter(X,Y)
plt.show()

# %%
# by using plt.plot()
plt.plot(X,Y) # all these methods works for plotting
# numeric data

# %%
#d DataFrame Slicing 

# using loc -- .loc[rowno,column-name]
ds.loc[0:10,['Country Code','Short Name']]
# Out:
#    Country Code            Short Name
# 0           ABW                 Aruba
# 1           ADO               Andorra
# 2           AFG           Afghanistan
# 3           AGO                Angola
# 4           ALB               Albania
# 5           ARB            Arab World
# 6           ARE  United Arab Emirates
# 7           ARG             Argentina
# 8           ARM               Armenia
# 9           ASM        American Samoa
# 10          ATG   Antigua and Barbuda

# %%
#using iloc -- .iloc[row-no,column-no]
ds.iloc[0:5,0:5]
# Out:
#   Country Code   Short Name   Table Name                     Long Name  \
# 0          ABW        Aruba        Aruba                         Aruba
# 1          ADO      Andorra      Andorra       Principality of Andorra
# 2          AFG  Afghanistan  Afghanistan  Islamic State of Afghanistan
# 3          AGO       Angola       Angola   People's Republic of Angola
# 4          ALB      Albania      Albania           Republic of Albania
#
#   2-alpha code
# 0           AW
# 1           AD
# 2           AF
# 3           AO
# 4           AL

# %%
#using column name and row no
ds['Table Name'][0:10]
# Out:
# 0                   Aruba
# 1                 Andorra
# 2             Afghanistan
# 3                  Angola
# 4                 Albania
# 5              Arab World
# 6    United Arab Emirates
# 7               Argentina
# 8                 Armenia
# 9          American Samoa
# Name: Table Name, dtype: object

# %%
# selecting 


ds.head(2)
# Out:
#   Country Code Short Name Table Name                Long Name 2-alpha code  \
# 0          ABW      Aruba      Aruba                    Aruba           AW
# 1          ADO    Andorra    Andorra  Principality of Andorra           AD
#
#    Currency Unit                                      Special Notes  \
# 0  Aruban florin  SNA data for 2000-2011 are updated from offici...
# 1           Euro  The base year has changed to 2000. Price valua...
#
#                       Region Income Group WB-2 code  ...  \
# 0  Latin America & Caribbean  High income        AW  ...
# 1      Europe & Central Asia  High income        AD  ...
#
#   Government Accounting concept IMF data dissemination standard  \
# 0                           NaN                             NaN
# 1                           NaN                             NaN
#
#                             Latest population census Latest household survey  \
# 0                                               2010                     NaN
# ...

# %%
#using column name and row no
ds['Table Name'][0]
# Out:
# 'Aruba'

# %%
#extracting values
# u can extract using normal indexing or loc or iloc or ix

ds.iloc[-1,10]
# Out:
# '2009'

# %%
#d conditional selections
ds.loc[(ds['Latest trade data']>2010)]
# Out:
#     Country Code            Short Name            Table Name  \
# 0            ABW                 Aruba                 Aruba
# 1            ADO               Andorra               Andorra
# 2            AFG           Afghanistan           Afghanistan
# 4            ALB               Albania               Albania
# 6            ARE  United Arab Emirates  United Arab Emirates
# ..           ...                   ...                   ...
# 257          WSM                 Samoa                 Samoa
# 258          YEM                 Yemen           Yemen, Rep.
# 259          ZAF          South Africa          South Africa
# 261          ZMB                Zambia                Zambia
# 262          ZWE              Zimbabwe              Zimbabwe
#
#                         Long Name 2-alpha code       Currency Unit  \
# 0                           Aruba           AW       Aruban florin
# 1         Principality of Andorra           AD                Euro
# ...

# %%
ds.loc[(ds['Latest trade data']>2010)].shape
# Out:
# (172, 31)

# %%
ds.loc[(ds['Latest trade data']<2010)].shape
# Out:
# (14, 31)

# %%
ds.loc[(ds['Latest industrial data']>2010) & (ds['Latest trade data']<2010) ]
# Out:
#    Country Code Short Name Table Name         Long Name 2-alpha code  \
# 66          ERI    Eritrea    Eritrea  State of Eritrea           ER
#
#      Currency Unit                                      Special Notes  \
# 66  Eritrean nakfa  April 2013 database update: Based on IMF data,...
#
#                 Region Income Group WB-2 code  ...  \
# 66  Sub-Saharan Africa   Low income        ER  ...
#
#    Government Accounting concept IMF data dissemination standard  \
# 66                           NaN                             NaN
#
#    Latest population census              Latest household survey  \
# 66                     1984  Demographic and Health Survey, 2002
#
#    Source of most recent Income and expenditure data  \
# 66                        Priority survey (PS), 1993
#
#    Vital registration complete Latest agricultural census  \
# 66                         NaN                        NaN
#
#    Latest industrial data Latest trade data Latest water withdrawal data
# ...
