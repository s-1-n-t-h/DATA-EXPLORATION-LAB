# %%
import pandas as pd

# %%
#a viewing data

pd.read_csv('california_housing_test.csv').head()
# Out:
#    longitude  latitude  housing_median_age  total_rooms  total_bedrooms  \
# 0    -122.05     37.37                27.0       3885.0           661.0
# 1    -118.30     34.26                43.0       1510.0           310.0
# 2    -117.81     33.78                27.0       3589.0           507.0
# 3    -118.36     33.82                28.0         67.0            15.0
# 4    -119.67     36.33                19.0       1241.0           244.0
#
#    population  households  median_income  median_house_value
# 0      1537.0       606.0         6.6085            344700.0
# 1       809.0       277.0         3.5990            176500.0
# 2      1484.0       495.0         5.7934            270500.0
# 3        49.0        11.0         6.1359            330000.0
# 4       850.0       237.0         2.9375             81700.0

# %%
#b Data Set Description

ds = pd.read_csv('california_housing_test.csv')

# %%
ds.describe()
# Out:
#          longitude    latitude  housing_median_age   total_rooms  \
# count  3000.000000  3000.00000         3000.000000   3000.000000
# mean   -119.589200    35.63539           28.845333   2599.578667
# std       1.994936     2.12967           12.555396   2155.593332
# min    -124.180000    32.56000            1.000000      6.000000
# 25%    -121.810000    33.93000           18.000000   1401.000000
# 50%    -118.485000    34.27000           29.000000   2106.000000
# 75%    -118.020000    37.69000           37.000000   3129.000000
# max    -114.490000    41.92000           52.000000  30450.000000
#
#        total_bedrooms    population  households  median_income  \
# count     3000.000000   3000.000000  3000.00000    3000.000000
# mean       529.950667   1402.798667   489.91200       3.807272
# std        415.654368   1030.543012   365.42271       1.854512
# min          2.000000      5.000000     2.00000       0.499900
# ...

# %%
#c Descrive as category

ds.dtypes
# Out:
# longitude             float64
# latitude              float64
# housing_median_age    float64
# total_rooms           float64
# total_bedrooms        float64
# population            float64
# households            float64
# median_income         float64
# median_house_value    float64
# dtype: object

# %%
#d Handling Duplicates

ds.shape
# Out:
# (3000, 9)

# %%
ds_new = ds.drop_duplicates(subset=['housing_median_age'],keep='first')

# %%
ds_new.shape
# Out:
# (52, 9)

# %%
#e Number of Observations per Category
ds.columns
# Out:
# Index(['longitude', 'latitude', 'housing_median_age', 'total_rooms',
#        'total_bedrooms', 'population', 'households', 'median_income',
#        'median_house_value'],
#       dtype='object')

# %%
for i in ds.columns:
  print(ds.groupby(i).size())
# Out:
# longitude
# -124.18    1
# -124.17    1
# -124.16    4
# -124.15    1
# -124.14    3
#           ..
# -114.98    1
# -114.62    1
# -114.61    1
# -114.55    1
# -114.49    1
# Length: 607, dtype: int64
# latitude
# 32.56    1
# 32.57    3
# 32.58    6
# 32.59    2
# 32.60    1
#         ..
# 41.31    1
# 41.54    1
# 41.63    1
# 41.80    1
# 41.92    1
# Length: 587, dtype: int64
# housing_median_age
# 1.0       2
# 2.0       6
# 3.0      12
# 4.0      28
# 5.0      39
# 6.0      25
# 7.0      20
# 8.0      25
# 9.0      27
# 10.0     30
# 11.0     41
# 12.0     41
# 13.0     41
# 14.0     57
# 15.0     77
# 16.0    107
# 17.0    100
# 18.0     76
# 19.0     76
# 20.0     63
# 21.0     61
# 22.0     60
# 23.0     53
# 24.0     75
# 25.0     86
# 26.0     88
# 27.0     74
# 28.0     58
# 29.0     75
# 30.0     76
# 31.0     57
# 32.0     91
# 33.0     85
# 34.0    102
# 35.0    118
# 36.0    115
# 37.0     88
# 38.0     64
# 39.0     55
# 40.0     43
# 41.0     56
# 42.0     51
# ...

# %%
#f Column Cleanup
import numpy as np

# %%
df = pd.DataFrame({'name':['Alfred','Batman','Catwoman'],
                  'toy':[np.nan,'Batmobile','Bullwhip'],
                  'born':[pd.NaT,pd.Timestamp("1940-04-25"),pd.NaT]})

# %%
df.shape
# Out:
# (3, 3)

# %%
df
# Out:
#        name        toy       born
# 0    Alfred        NaN        NaT
# 1    Batman  Batmobile 1940-04-25
# 2  Catwoman   Bullwhip        NaT

# %%
df.dropna(axis=1).shape
# Out:
# (3, 1)

# %%
df.dropna(axis=1)
# Out:
#        name
# 0    Alfred
# 1    Batman
# 2  Catwoman

# %%
pd.read_csv('california_housing_test.csv').iloc[:,0:4].head()
# Out:
#    longitude  latitude  housing_median_age  total_rooms
# 0    -122.05     37.37                27.0       3885.0
# 1    -118.30     34.26                43.0       1510.0
# 2    -117.81     33.78                27.0       3589.0
# 3    -118.36     33.82                28.0         67.0
# 4    -119.67     36.33                19.0       1241.0
