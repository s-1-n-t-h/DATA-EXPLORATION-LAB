# %%
import pandas as pd

# %%
# a - Histogram

# %%
df.hist()
# Out:
# array([[<AxesSubplot:title={'center':'Height'}>]], dtype=object)

# %%
# b - scatterplot

# %%
data = {'Name':['Lokesh','Praveen','Manoj','Sujitha','Srivalli','Martha'],
        'Height':[5.7,5.6,6.0,5.5,5.9,5.6]}

# %%
df = pd.DataFrame(data)

# %%
df.plot.scatter(x='Name',y='Height')
# Out:
# <AxesSubplot:xlabel='Name', ylabel='Height'>

# %%
#c - Area Plot

# %%
df.plot.area()
# Out:
# <AxesSubplot:>

# %%
#d - Line Plot

# %%
df.plot.line()
# Out:
# <AxesSubplot:>

# %%
#e - Kernel Denity Plot (KDE)

# %%
df.plot.kde()
# Out:
# <AxesSubplot:ylabel='Density'>

# %%
\
