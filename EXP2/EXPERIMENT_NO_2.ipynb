# %%
import pandas as pd

# %%
dic = {
    'name':['harry','rohan','skilff','shubh'],
    'marks':[12,34,24,17],
    'city':['rampur','kolkata','barelly','antarctica']
}

# %%
df = pd.DataFrame(dic)

# %%
df
# Out:
#      name  marks        city
# 0   harry     12      rampur
# 1   rohan     34     kolkata
# 2  skilff     24     barelly
# 3   shubh     17  antarctica

# %%
#a writing to a csv file

df.to_csv('friends.csv')

# %%
df.to_csv('friend.csv',index=False)

# %%
#b reading from a csv

pd.read_csv('friend.csv')
# Out:
#      name  marks        city
# 0   harry     12      rampur
# 1   rohan     34     kolkata
# 2  skilff     24     barelly
# 3   shubh     17  antarctica

# %%
pd.read_csv('friends.csv')
# Out:
#    Unnamed: 0    name  marks        city
# 0           0   harry     12      rampur
# 1           1   rohan     34     kolkata
# 2           2  skilff     24     barelly
# 3           3   shubh     17  antarctica

# %%
#c reading from a excel file

data = pd.read_excel('data.xlsx',sheet_name='IT')

# %%
data.head()
# Out:
#   JNTUK UNIVERSITY COLLEGE OF ENGINEERING VIZIANAGARAM (AUTONOMOUS)  \
# 0                  Branch   : Information Technology
# 1                                               S.No
# 2                                                1.0
# 3                                                2.0
# 4                                                3.0
#
#        Unnamed: 1 Unnamed: 2   Unnamed: 3                       Unnamed: 4  \
# 0             NaN        NaN          NaN                              NaN
# 1  Hall Ticket No       Rank  Roll Number            Name of the Candidate
# 2   50188030116.0    15572.0   21VV1A1201                       AARI ESWAR
# 3   50161030014.0     8968.0   21VV1A1202   AMARA LINGESWARA RAO BODDAPATI
# 4   50161040115.0     9905.0   21VV1A1203  ANDROTHU HARSHA VIVEK GANGADHAR
#
#   Unnamed: 5 Unnamed: 6 Unnamed: 7     Unnamed: 8 Unnamed: 9 Unnamed: 10
# 0        NaN        NaN        NaN            NaN        NaN         NaN
# ...

# %%
#d writing to a Excel File

data.to_excel('new_data.xlsx',sheet_name='IT')
