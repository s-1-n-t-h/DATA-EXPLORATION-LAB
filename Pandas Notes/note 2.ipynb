# %%
# handling excel files (xlxs)

# %%
import pandas as pd
import numpy as np

# %%
data = pd.read_excel(r"C:\Users\YASH\Downloads\juniors.xlsx", sheet_name='IT')

# %%
data
# Out:
#    JNTUK UNIVERSITY COLLEGE OF ENGINEERING VIZIANAGARAM (AUTONOMOUS)  \
# 0                   Branch   : Information Technology
# 1                                                S.No
# 2                                                 1.0
# 3                                                 2.0
# 4                                                 3.0
# ..                                                ...
# 66                                               65.0
# 67                                                NaN
# 68                                                NaN
# 69                                                NaN
# 70                                                NaN
#
#         Unnamed: 1 Unnamed: 2   Unnamed: 3                       Unnamed: 4  \
# 0              NaN        NaN          NaN                              NaN
# 1   Hall Ticket No       Rank  Roll Number            Name of the Candidate
# ...

# %%
data = pd.read_excel(r"C:\Users\YASH\Downloads\juniors.xlsx", sheet_name='CSE')

# %%
data
# Out:
#    JNTUK UNIVERSITY COLLEGE OF ENGINEERING VIZIANAGARAM (AUTONOMOUS)  \
# 0           Branch   : Computer Science & Engineering
# 1                                                S.No
# 2                                                 1.0
# 3                                                 2.0
# 4                                                 3.0
# ..                                                ...
# 64                                               63.0
# 65                                                NaN
# 66                                                NaN
# 67                                                NaN
# 68                                                NaN
#
#        Unnamed: 1 Unnamed: 2   Unnamed: 3                       Unnamed: 4  \
# 0             NaN        NaN          NaN                              NaN
# 1        H Number       Rank  Roll Number            Name of the Candidate
# ...

# %%
data.iloc[64,4] = 'worst fellow'

# %%
data.loc[64]
# Out:
# JNTUK UNIVERSITY COLLEGE OF ENGINEERING VIZIANAGARAM (AUTONOMOUS)             63.0
# Unnamed: 1                                                           50380010056.0
# Unnamed: 2                                                                 14796.0
# Unnamed: 3                                                              21VV1A1263
# Unnamed: 4                                                            worst fellow
# Unnamed: 5                                                                       F
# Unnamed: 6                                                                    BC_D
# Unnamed: 7                                                                      AU
# Unnamed: 8                                                             BC_D_GEN_AU
# Unnamed: 9                                                                     3.0
# Unnamed: 10                                                                    NaN
# Name: 64, dtype: object

# %%
data.tail(10)
# Out:
#    JNTUK UNIVERSITY COLLEGE OF ENGINEERING VIZIANAGARAM (AUTONOMOUS)  \
# 61                                               60.0
# 62                                               61.0
# 63                                               62.0
# 64                                               63.0
# 65                                               64.0
# 66                                               65.0
# 67                                                NaN
# 68                                                NaN
# 69                                                NaN
# 70                                                NaN
#
#        Unnamed: 1 Unnamed: 2  Unnamed: 3  \
# 61  50982010239.0    14646.0  21VV1A1260
# 62  50182010017.0    19197.0  21VV1A1261
# 63  50587010060.0    14115.0  21VV1A1262
# 64  50380010056.0    14796.0  21VV1A1263
# 65  50888030075.0    12070.0  21VV1A1264
# 66  50578020007.0    23603.0  21VV1A1265
# 67            NaN        NaN         NaN
# ...

# %%
data.to_excel('data.xlsx',sheet_name='IT')
